# %%
import pandas as pd
import os, sys
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import statistics as st
sys.path.insert(0,'../scripts/')
from process import plot_scatter,plot_heatmap

# %%
tele_dataf = pd.read_csv("telecom2.csv", na_values=[None, "?"])
tele_dataf.drop("Unnamed: 0",axis=1,inplace=True)

# %%
tele_dataf.head(5)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 45 columns]

# %%
tele_dataf.head(5)
# Out:
#       Bearer Id            Start  Start ms              End  End ms  \
# 0  1.311448e+19   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1  1.311448e+19   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2  1.311448e+19   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3  1.311448e+19   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4  1.311448e+19  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0  9.16456699548519E+015  ...          15854611.0           2501332.0
# 1                L77566A  ...          20247395.0          19111729.0
# 2                D42335A  ...          19725661.0          14699576.0
# 3                T21824A  ...          21388122.0          15146643.0
# 4                D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 45 columns]

# %% [markdown]
# Top 10 handsets used by the customers

# %%
handset_type= tele_dataf['Handset Type'].value_counts()[0:10]
handset_type.plot.bar(x='Handset Type', title="Top 10 handsets used by customers", stacked=True, color='#3492eb')
handset_type
# Out:
# Handset Type
# Huawei B528S-23A                19727
# Apple iPhone 6S (A1688)          9395
# Apple iPhone 6 (A1586)           8993
# undefined                        8904
# Apple iPhone 7 (A1778)           6279
# Apple iPhone Se (A1723)          5165
# Apple iPhone 8 (A1905)           4977
# Apple iPhone Xr (A2105)          4556
# Samsung Galaxy S8 (Sm-G950F)     4464
# Apple iPhone X (A1901)           3806
# Name: count, dtype: int64

# %% [markdown]
# Top 3 handset manufacturers

# %%
Handset_manufacturers = tele_dataf['Handset Manufacturer'].value_counts()[0:3]
Handset_manufacturers.plot.bar(x='Handset Manufacturer', title="Top 3 handset manufacturers", stacked=True, color='#343aeb')
Handset_manufacturers
# Out:
# Handset Manufacturer
# Apple      59339
# Samsung    40429
# Huawei     34296
# Name: count, dtype: int64

# %% [markdown]
# Top 5 handsets per top 3 handset manufacturer

# %%
top_apple = tele_dataf.loc[tele_dataf['Handset Manufacturer'] == 'Apple']
top_apple = top_apple.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
top_apple.columns = ['count']
top_apple=top_apple.nlargest(5, 'count')
top_apple.plot.bar(y='count', title="Top 5 Apple Handsets", stacked=True, color='#ec2123')
top_apple
# Out:
#                                               count
# Handset Manufacturer Handset Type
# Apple                Apple iPhone 6S (A1688)   9395
#                      Apple iPhone 6 (A1586)    8993
#                      Apple iPhone 7 (A1778)    6279
#                      Apple iPhone Se (A1723)   5165
#                      Apple iPhone 8 (A1905)    4977

# %%
top_samsung = tele_dataf.loc[tele_dataf['Handset Manufacturer'] == 'Samsung']
top_samsung = top_samsung.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
top_samsung.columns = ['count']
top_samsung=top_samsung.nlargest(5, 'count')
top_samsung.plot.bar(y='count', title="Top 5 Samsung Handsets", stacked=True, color='#ffc206')
top_samsung
# Out:
#                                                    count
# Handset Manufacturer Handset Type
# Samsung              Samsung Galaxy S8 (Sm-G950F)   4464
#                      Samsung Galaxy A5 Sm-A520F     3700
#                      Samsung Galaxy J5 (Sm-J530)    3675
#                      Samsung Galaxy J3 (Sm-J330)    3456
#                      Samsung Galaxy S7 (Sm-G930X)   3171

# %%
top_huawei = tele_dataf.loc[tele_dataf['Handset Manufacturer'] == 'Huawei']
top_huawei = top_huawei.groupby(['Handset Manufacturer', 'Handset Type']).agg({'Handset Type': ['count']})
top_huawei.columns = ['count']
top_huawei=top_huawei.nlargest(5, 'count')
top_huawei.plot.bar(y='count', title="Top 5 Huawei Handsets", stacked=True, color='#3d85c6')
top_huawei
# Out:
#                                                      count
# Handset Manufacturer Handset Type
# Huawei               Huawei B528S-23A                19727
#                      Huawei E5180                     2074
#                      Huawei P20 Lite Huawei Nova 3E   2012
#                      Huawei P20                       1475
#                      Huawei Y6 2018                    996

# %% [markdown]
# The analysis's conclusion reveals:
#
# • The Huawei B528S-23A is the most popular phone model among customers. It is produced by Huawei.
#
# • The top three manufacturers of smartphones are: Apple with 59339, Samsung with 40429, and Huawei with 34296.
#
# • Customers do not prefer Apple's handsets over Samsung's, and Samsung manufacturers the same as Apple does.
#
# • It is advised that Huawei Handsets manufacturers expand their manufacturing capacity in order to better serve clients.

# %% [markdown]
# Task 2.1

# %% [markdown]
# number of xDR sessions

# %%
xDR_session_per_user = tele_dataf.groupby('MSISDN/Number')['Bearer Id'].sum()
xDR_session_per_user
# Out:
# MSISDN/Number
# 3.360100e+10    1.311448e+19
# 3.360100e+10    7.349883e+18
# 3.360100e+10    7.349883e+18
# 3.360101e+10    1.304243e+19
# 3.360101e+10    1.462771e+19
#                     ...
# 3.379000e+10    1.304243e+19
# 3.379000e+10    1.311448e+19
# 3.197021e+12    7.277826e+18
# 3.370000e+14    7.349883e+18
# 8.823971e+14    7.277826e+18
# Name: Bearer Id, Length: 106471, dtype: float64

# %% [markdown]
# Session duration

# %%
session_duration_per_user = tele_dataf.groupby('MSISDN/Number')['Dur. (ms)'].sum()
session_duration_per_user
# Out:
# MSISDN/Number
# 3.360100e+10    116720.0
# 3.360100e+10    181230.0
# 3.360100e+10    134969.0
# 3.360101e+10     49878.0
# 3.360101e+10     37104.0
#                   ...
# 3.379000e+10      8810.0
# 3.379000e+10    140988.0
# 3.197021e+12    877385.0
# 3.370000e+14    253030.0
# 8.823971e+14    869844.0
# Name: Dur. (ms), Length: 106471, dtype: float64

# %% [markdown]
# the total download (DL) and upload (UL) data

# %%
total_ul = tele_dataf.groupby('MSISDN/Number')['Total UL (Bytes)'].sum()
total_dl = tele_dataf.groupby('MSISDN/Number')['Total DL (Bytes)'].sum()
print(f'total upload:\n{total_ul}\n\ntotal download:\n{total_dl}\n\ntotal upload + download: {total_dl+total_ul}')
# Out:
# total upload:
# MSISDN/Number
# 3.360100e+10    36053108.0
# 3.360100e+10    36104459.0
# 3.360100e+10    39306820.0
# 3.360101e+10    20327526.0
# 3.360101e+10    94280527.0
#                    ...
# 3.379000e+10    26716429.0
# 3.379000e+10    35732243.0
# 3.197021e+12    37295915.0
# 3.370000e+14    56652839.0
# 8.823971e+14    60456049.0
# Name: Total UL (Bytes), Length: 106471, dtype: float64
#
# total download:
# MSISDN/Number
# 3.360100e+10    8.426375e+08
# 3.360100e+10    1.207552e+08
# 3.360100e+10    5.566597e+08
# 3.360101e+10    4.019932e+08
# 3.360101e+10    1.363130e+09
#                     ...
# 3.379000e+10    6.879252e+08
# 3.379000e+10    4.445751e+08
# 3.197021e+12    1.948281e+08
# 3.370000e+14    5.396350e+08
# 8.823971e+14    7.869760e+07
# Name: Total DL (Bytes), Length: 106471, dtype: float64
#
# total upload + download: MSISDN/Number
# 3.360100e+10    8.786906e+08
# 3.360100e+10    1.568596e+08
# 3.360100e+10    5.959665e+08
# 3.360101e+10    4.223207e+08
# 3.360101e+10    1.457411e+09
#                     ...
# 3.379000e+10    7.146416e+08
# 3.379000e+10    4.803073e+08
# 3.197021e+12    2.321240e+08
# 3.370000e+14    5.962878e+08
# 8.823971e+14    1.391536e+08
# Length: 106471, dtype: float64

# %% [markdown]
# the total data volume (in Bytes) during this session for each application

# %%
total_google = tele_dataf['Google DL (Bytes)'] + tele_dataf['Google UL (Bytes)']
total_email = tele_dataf['Email DL (Bytes)'] + tele_dataf['Email UL (Bytes)']
total_gaming = tele_dataf['Gaming DL (Bytes)'] + tele_dataf['Gaming UL (Bytes)']

total_youtube = tele_dataf['Youtube DL (Bytes)'] + tele_dataf['Youtube UL (Bytes)']
total_netflix = tele_dataf['Netflix DL (Bytes)'] + tele_dataf['Netflix UL (Bytes)']
total_social = tele_dataf['Social Media DL (Bytes)'] + tele_dataf['Social Media UL (Bytes)']
total_other = tele_dataf['Other DL (Bytes)'] + tele_dataf['Other UL (Bytes)']

# add the total data volumes on the main data set
tele_dataf['total_google'] = total_google
tele_dataf['total_email'] = total_email
tele_dataf['total_gaming'] = total_gaming

tele_dataf['total_youtube'] = total_youtube
tele_dataf['total_netflix'] = total_netflix
tele_dataf['total_social'] = total_social
tele_dataf['total_other'] = total_other

# aggregate total data volume per application
# google
total_data_volume_per_user_google = tele_dataf.groupby('MSISDN/Number')['total_google'].sum()
print(f'{total_data_volume_per_user_google}\n')

# email
total_data_volume_per_user_email = tele_dataf.groupby('MSISDN/Number')['total_email'].sum()
print(f'{total_data_volume_per_user_email}\n')

# gaming
total_data_volume_per_user_gaming = tele_dataf.groupby('MSISDN/Number')['total_gaming'].sum()
print(f'{total_data_volume_per_user_gaming}\n')

# youtube
total_data_volume_per_user_youtube = tele_dataf.groupby('MSISDN/Number')['total_youtube'].sum()
print(f'{total_data_volume_per_user_youtube}\n')

# netflix
total_data_volume_per_user_netflix = tele_dataf.groupby('MSISDN/Number')['total_netflix'].sum()
print(f'{total_data_volume_per_user_netflix}\n') 

# social
total_data_volume_per_user_social = tele_dataf.groupby('MSISDN/Number')['total_social'].sum()
print(f'{total_data_volume_per_user_social}\n')

# other
total_data_volume_per_user_other = tele_dataf.groupby('MSISDN/Number')['total_other'].sum()
print(f'{total_data_volume_per_user_other}\n')
# Out:
# MSISDN/Number
# 3.360100e+10     4389005.0
# 3.360100e+10     5334863.0
# 3.360100e+10     3443126.0
# 3.360101e+10     9678493.0
# 3.360101e+10    18499616.0
#                    ...
# 3.379000e+10     7531269.0
# 3.379000e+10     5429705.0
# 3.197021e+12    10438660.0
# 3.370000e+14     9830617.0
# 8.823971e+14     9218647.0
# Name: total_google, Length: 106471, dtype: float64
# MSISDN/Number
# 3.360100e+10    1331362.0
# 3.360100e+10    3307781.0
# 3.360100e+10    3205380.0
# 3.360101e+10    2284670.0
# 3.360101e+10    3305469.0
#                   ...
# 3.379000e+10    1006915.0
# 3.379000e+10    2514097.0
# 3.197021e+12    1520771.0
# 3.370000e+14    3318582.0
# 8.823971e+14    3330974.0
# Name: total_email, Length: 106471, dtype: float64
#
# MSISDN/Number
# 3.360100e+10    8.124587e+08
# 3.360100e+10    1.197501e+08
# 3.360100e+10    5.388277e+08
# 3.360101e+10    3.911261e+08
# 3.360101e+10    1.314798e+09
#                     ...
# 3.379000e+10    6.603614e+08
# 3.379000e+10    4.370033e+08
# 3.197021e+12    1.780487e+08
# 3.370000e+14    5.101427e+08
# 8.823971e+14    4.307026e+07
# Name: total_gaming, Length: 106471, dtype: float64
#
# MSISDN/Number
# 3.360100e+10    21624548.0
# 3.360100e+10    12432223.0
# 3.360100e+10    21333570.0
# 3.360101e+10     6977321.0
# 3.360101e+10    41533002.0
#                    ...
# 3.379000e+10    26647843.0
# 3.379000e+10    19851572.0
# 3.197021e+12    11959905.0
# 3.370000e+14    36734940.0
# 8.823971e+14    40940710.0
# Name: total_youtube, Length: 106471, dtype: float64
#
# MSISDN/Number
# 3.360100e+10    27180981.0
# 3.360100e+10    11221763.0
# 3.360100e+10    19353900.0
# 3.360101e+10     1942092.0
# 3.360101e+10    49201724.0
#                    ...
# 3.379000e+10    14902538.0
# 3.379000e+10     8531060.0
# 3.197021e+12    26592300.0
# 3.370000e+14    30905042.0
# 8.823971e+14    28846230.0
# Name: total_netflix, Length: 106471, dtype: float64
#
# MSISDN/Number
# 3.360100e+10    2232135.0
# 3.360100e+10    2660565.0
# 3.360100e+10    3195623.0
# 3.360101e+10     280294.0
# 3.360101e+10    2912542.0
#                   ...
# 3.379000e+10     300183.0
# 3.379000e+10     498569.0
# 3.197021e+12     715224.0
# 3.370000e+14     521566.0
# 8.823971e+14    1546088.0
# Name: total_social, Length: 106471, dtype: float64
#
# MSISDN/Number
# 3.360100e+10    386570872.0
# 3.360100e+10    281710071.0
# 3.360100e+10    501693672.0
# 3.360101e+10     35279702.0
# 3.360101e+10    804804484.0
#                    ...
# 3.379000e+10    295282817.0
# 3.379000e+10    211115113.0
# 3.197021e+12    470526473.0
# 3.370000e+14    149188439.0
# 8.823971e+14    401360457.0
# Name: total_other, Length: 106471, dtype: float64

# %% [markdown]
# Task 2.2

# %% [markdown]
# Analyze the basic metrics (mean, median, etc) in the Dataset

# %%
relevant_features = ['Dur. (ms)', 'Activity Duration DL (ms)', 'Activity Duration UL (ms)', 'Social Media DL (Bytes)', 'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)', 'Total UL (Bytes)', 'Total DL (Bytes)', 'total_google', 'total_email', 'total_gaming', 'total_youtube', 'total_netflix', 'total_social', 'total_other']


print("Mean\n", tele_dataf[relevant_features].mean(), '\n')
print("Median\n", tele_dataf[relevant_features].median(), '\n')

mode_series = pd.Series(tele_dataf[relevant_features].mode().values[0], index=relevant_features)
print("Mode\n", mode_series, '\n')

print("Highest\n", tele_dataf[relevant_features].max(), '\n')
print("lowest\n", tele_dataf[relevant_features].min(), '\n')
# Out:
# Mean
#  Dur. (ms)                    1.050841e+05
# Activity Duration DL (ms)    1.837842e+06
# Activity Duration UL (ms)    1.414773e+06
# Social Media DL (Bytes)      1.795144e+06
# Social Media UL (Bytes)      3.292209e+04
# Google DL (Bytes)            5.751770e+06
# Google UL (Bytes)            2.056293e+06
# Email DL (Bytes)             1.791785e+06
# Email UL (Bytes)             4.674035e+05
# Youtube DL (Bytes)           1.163387e+07
# Youtube UL (Bytes)           1.100857e+07
# Netflix DL (Bytes)           1.162724e+07
# Netflix UL (Bytes)           1.100190e+07
# Gaming DL (Bytes)            4.220642e+08
# Gaming UL (Bytes)            8.289600e+06
# Other DL (Bytes)             4.211525e+08
# Other UL (Bytes)             8.262685e+06
# Total UL (Bytes)             4.111937e+07
# Total DL (Bytes)             4.546640e+08
# total_google                 7.808063e+06
# total_email                  2.259188e+06
# total_gaming                 4.303538e+08
# total_youtube                2.264244e+07
# total_netflix                2.262914e+07
# total_social                 1.828066e+06
# total_other                  4.294152e+08
# dtype: float64
#
# Median
#  Dur. (ms)                        86399.0
# Activity Duration DL (ms)        39018.5
# Activity Duration UL (ms)        46481.0
# Social Media DL (Bytes)        1793860.5
# Social Media UL (Bytes)          32917.0
# Google DL (Bytes)              5767399.0
# Google UL (Bytes)              2054221.5
# Email DL (Bytes)               1793641.5
# Email UL (Bytes)                466419.0
# Youtube DL (Bytes)            11615961.5
# Youtube UL (Bytes)            11012318.0
# Netflix DL (Bytes)            11642380.0
# Netflix UL (Bytes)            10999370.5
# Gaming DL (Bytes)            423466906.5
# Gaming UL (Bytes)              8291649.5
# Other DL (Bytes)             421861759.0
# Other UL (Bytes)               8266016.0
# Total UL (Bytes)              41141959.5
# Total DL (Bytes)             455940800.5
# total_google                   7815669.0
# total_email                    2264186.0
# total_gaming                 431658476.5
# total_youtube                 22661313.5
# total_netflix                 22636325.0
# total_social                   1825931.0
# total_other                  430043829.5
# dtype: float64
#
# Mode
#  Dur. (ms)                       86399.0
# Activity Duration DL (ms)           0.0
# Activity Duration UL (ms)           0.0
# Social Media DL (Bytes)        152013.0
# Social Media UL (Bytes)         30810.0
# Google DL (Bytes)             3991481.0
# Google UL (Bytes)             3426526.0
# Email DL (Bytes)              1829513.0
# Email UL (Bytes)                53137.0
# Youtube DL (Bytes)           18869169.0
# Youtube UL (Bytes)            3398443.0
# Netflix DL (Bytes)            2097111.0
# Netflix UL (Bytes)            1751610.0
# Gaming DL (Bytes)            88731721.0
# Gaming UL (Bytes)            15304673.0
# Other DL (Bytes)             28616268.0
# Other UL (Bytes)              4514572.0
# Total UL (Bytes)             19362459.0
# Total DL (Bytes)             74126119.0
# total_google                  5240092.0
# total_email                    648993.0
# total_gaming                 15151281.0
# total_youtube                18836800.0
# total_netflix                 3192097.0
# total_social                   154418.0
# total_other                  54037059.0
# dtype: float64
#
# Highest
#  Dur. (ms)                      1859336.0
# Activity Duration DL (ms)    136536461.0
# Activity Duration UL (ms)    144911293.0
# Social Media DL (Bytes)        3586064.0
# Social Media UL (Bytes)          65870.0
# Google DL (Bytes)             11462832.0
# Google UL (Bytes)              4121357.0
# Email DL (Bytes)               3586146.0
# Email UL (Bytes)                936418.0
# Youtube DL (Bytes)            23259098.0
# Youtube UL (Bytes)            22011962.0
# Netflix DL (Bytes)            23259189.0
# Netflix UL (Bytes)            22011955.0
# Gaming DL (Bytes)            843441889.0
# Gaming UL (Bytes)             16558794.0
# Other DL (Bytes)             843442489.0
# Other UL (Bytes)              16558816.0
# Total UL (Bytes)              78331311.0
# Total DL (Bytes)             902969616.0
# total_google                  15528782.0
# total_email                    4518036.0
# total_gaming                 859202784.0
# total_youtube                 45190078.0
# total_netflix                 45198153.0
# total_social                   3650861.0
# total_other                  859520934.0
# dtype: float64
#
# lowest
#  Dur. (ms)                       7142.0
# Activity Duration DL (ms)          0.0
# Activity Duration UL (ms)          0.0
# Social Media DL (Bytes)           12.0
# Social Media UL (Bytes)            0.0
# Google DL (Bytes)                207.0
# Google UL (Bytes)                  3.0
# Email DL (Bytes)                  14.0
# Email UL (Bytes)                   2.0
# Youtube DL (Bytes)                53.0
# Youtube UL (Bytes)               105.0
# Netflix DL (Bytes)                42.0
# Netflix UL (Bytes)                35.0
# Gaming DL (Bytes)               2516.0
# Gaming UL (Bytes)                 59.0
# Other DL (Bytes)                3290.0
# Other UL (Bytes)                 148.0
# Total UL (Bytes)             2866892.0
# Total DL (Bytes)             7114041.0
# total_google                   40330.0
# total_email                     8359.0
# total_gaming                  306358.0
# total_youtube                  78903.0
# total_netflix                  98432.0
# total_social                    1563.0
# total_other                   149045.0
# dtype: float64

# %% [markdown]
# Non-Graphical Univariate Analysis

# %% [markdown]
# Computing dispersion parameters for each quantitative variable

# %%
sub_relevant_features = ['MSISDN/Number','Dur. (ms)','Total UL (Bytes)', 'Total DL (Bytes)', 'total_google','total_email','total_gaming','total_youtube','total_netflix','total_social', 'total_other']

tele_dataf[sub_relevant_features].describe()
# Out:
#        MSISDN/Number     Dur. (ms)  Total UL (Bytes)  Total DL (Bytes)  \
# count   1.485060e+05  1.485060e+05      1.485060e+05      1.485060e+05
# mean    4.190654e+10  1.050841e+05      4.111937e+07      4.546640e+08
# std     2.450976e+12  8.107274e+04      1.127844e+07      2.441791e+08
# min     3.360100e+10  7.142000e+03      2.866892e+06      7.114041e+06
# 25%     3.365131e+10  5.824875e+04      3.321828e+07      2.431263e+08
# 50%     3.366371e+10  8.639900e+04      4.114196e+07      4.559408e+08
# 75%     3.368352e+10  1.329328e+05      4.903252e+07      6.657542e+08
# max     8.823971e+14  1.859336e+06      7.833131e+07      9.029696e+08
#
#        total_google   total_email  total_gaming  total_youtube  total_netflix  \
# count  1.485060e+05  1.485060e+05  1.485060e+05   1.485060e+05   1.485060e+05
# mean   7.808063e+06  2.259188e+06  4.303538e+08   2.264244e+07   2.262914e+07
# std    3.516724e+06  1.071152e+06  2.440569e+08   9.247684e+06   9.260477e+06
# min    4.033000e+04  8.359000e+03  3.063580e+05   7.890300e+04   9.843200e+04
# 25%    4.944994e+06  1.359336e+06  2.187362e+08   1.599374e+07   1.598016e+07
# 50%    7.815669e+06  2.264186e+06  4.316585e+08   2.266131e+07   2.263632e+07
# 75%    1.068307e+07  3.160024e+06  6.415282e+08   2.929824e+07   2.928832e+07
# max    1.552878e+07  4.518036e+06  8.592028e+08   4.519008e+07   4.519815e+07
#
#        total_social   total_other
# count  1.485060e+05  1.485060e+05
# mean   1.828066e+06  4.294152e+08
# std    1.035638e+06  2.432284e+08
# min    1.563000e+03  1.490450e+05
# 25%    9.321828e+05  2.186682e+08
# 50%    1.825931e+06  4.300438e+08
# 75%    2.727493e+06  6.398960e+08
# max    3.650861e+06  8.595209e+08

# %% [markdown]
# insight
#
# • Users upload less content than they download
#
# • A greater number of users submit data than download data
#
# • Gamers spend more money on games than on other channels like social media.

# %% [markdown]
# Graphical Univariate Analysis

# %%
for cols in relevant_features:
    print(cols)
    print("Mean", st.mean(tele_dataf[cols]))
   
    print("Mode", st.mode(tele_dataf[cols]))

    print("Median", st.median(tele_dataf[cols]))
    
    print("Variance", st.variance(tele_dataf[cols]))

    print("St. Dev", st.stdev(tele_dataf[cols]))
    print("Skew", tele_dataf[cols].skew())
    print('----')
# Out:
# Dur. (ms)
# Mean 105084.0549742098
# Mode 86399.0
# Median 86399.0
# Variance 6572789166.803576
# St. Dev 81072.7399734558
# Skew 3.9687972251832586
# ----
# Activity Duration DL (ms)
# Mean 1837842.1849150877
# Mode 0.0
# Median 39018.5
# Variance 32694427227190.77
# St. Dev 5717904.093913326
# Skew 5.852520525553382
# ----
# Activity Duration UL (ms)
# Mean 1414772.7676996216
# Mode 0.0
# Median 46481.0
# Variance 21732788866687.87
# St. Dev 4661843.93418397
# Skew 7.357988486520479
# ----
# Social Media DL (Bytes)
# Mean 1795144.1077936245
# Mode 2865700.0
# Median 1793860.5
# Variance 1072198340559.8076
# St. Dev 1035470.1060676777
# Skew -0.0017840427941975946
# ----
# Social Media UL (Bytes)
# Mean 32922.085511696496
# Mode 30810.0
# Median 32917.0
# Variance 361341635.26031506
# St. Dev 19008.988275558357
# Skew -0.00018635496084545364
# ----
# Google DL (Bytes)
# Mean 5751770.333185191
# Mode 6296014.0
# Median 5767399.0
# Variance 10947859331632.477
# St. Dev 3308754.951886355
# Skew -0.00864228060542617
# ----
# Google UL (Bytes)
# Mean 2056292.5512571882
# Mode 3426526.0
# Median 2054221.5
# Variance 1415955075598.8716
# St. Dev 1189939.105836459
# Skew 0.002352150971217084
# ----
# Email DL (Bytes)
# Mean 1791784.6950493583
# Mode 1829513.0
# Median 1793641.5
# Variance 1073204296011.4584
# St. Dev 1035955.7403728493
# Skew -0.0026607785002129847
# ----
# Email UL (Bytes)
# Mean 467403.4868961523
# Mode 370236.0
# Median 466419.0
# Variance 72890232781.59633
# St. Dev 269981.91195262753
# Skew 0.006817934312435383
# ----
# Youtube DL (Bytes)
# Mean 11633868.432925269
# Mode 18869169.0
# Median 11615961.5
# Variance 45040694665847.4
# St. Dev 6711236.448363848
# Skew 8.524542031181358e-05
# ----
# Youtube UL (Bytes)
# Mean 11008567.698039137
# Mode 3398443.0
# Median 11012318.0
# Variance 40266958853052.21
# St. Dev 6345625.174326972
# Skew -0.0008322263946983749
# ----
# Netflix DL (Bytes)
# Mean 11627241.739801759
# Mode 2097111.0
# Median 11642380.0
# Variance 45225540847376.68
# St. Dev 6724993.7432964705
# Skew -0.0023421197260017745
# ----
# Netflix UL (Bytes)
# Mean 11001902.340383554
# Mode 1751610.0
# Median 10999370.5
# Variance 40423271949979.97
# St. Dev 6357929.847834118
# Skew -0.0004372661485568094
# ----
# Gaming DL (Bytes)
# Mean 422064222.6951706
# Mode 137736955.0
# Median 423466906.5
# Variance 5.953809366666481e+16
# St. Dev 244004290.2628247
# Skew -0.0037858691065204854
# ----
# Gaming UL (Bytes)
# Mean 8289599.585855117
# Mode 15304673.0
# Median 8291649.5
# Variance 22867207080603.832
# St. Dev 4781966.863185464
# Skew -0.0022648458525621803
# ----
# Other DL (Bytes)
# Mean 421152465.35583746
# Mode 175335616.0
# Median 421861759.0
# Variance 5.912870044475681e+16
# St. Dev 243163937.38537136
# Skew 0.0010267704483625656
# ----
# Other UL (Bytes)
# Mean 8262685.049014854
# Mode 4514572.0
# Median 8266016.0
# Variance 22741511292205.75
# St. Dev 4768806.065694615
# Skew 0.0016108779672155409
# ----
# Total UL (Bytes)
# Mean 41119372.7969577
# Mode 31977269.0
# Median 41141959.5
# Variance 127203235930497.61
# St. Dev 11278441.201269686
# Skew -0.0020616208038286075
# ----
# Total DL (Bytes)
# Mean 454664032.00392574
# Mode 845059828.0
# Median 455940800.5
# Variance 5.962341980838531e+16
# St. Dev 244179073.24008197
# Skew -0.0034687196671957144
# ----
# total_google
# Mean 7808062.88444238
# Mode 5240092.0
# Median 7815669.0
# Variance 12367349958590.7
# St. Dev 3516724.322233788
# Skew -0.011086146194625137
# ----
# total_email
# Mean 2259188.1819455107
# Mode 1252392.0
# Median 2264186.0
# Variance 1147366488748.5027
# St. Dev 1071151.944753172
# Skew -0.006244433329997283
# ----
# total_gaming
# Mean 430353822.2810257
# Mode 202421084.0
# Median 431658476.5
# Variance 5.956376653880402e+16
# St. Dev 244056892.012506
# Skew -0.003535830251641954
# ----
# total_youtube
# Mean 22642436.130964406
# Mode 28588683.0
# Median 22661313.5
# Variance 85519656997773.12
# St. Dev 9247683.872071598
# Skew -0.005565738511525967
# ----
# total_netflix
# Mean 22629144.080185313
# Mode 18783247.0
# Median 22636325.0
# Variance 85756426457033.19
# St. Dev 9260476.578288678
# Skew -0.00080715228398259
# ----
# total_social
# Mean 1828066.193305321
# Mode 2601321.0
# Median 1825931.0
# Variance 1072545725549.2535
# St. Dev 1035637.8351283105
# Skew -0.0017872923216348164
# ----
# total_other
# Mean 429415150.40485233
# Mode 690339331.0
# Median 430043829.5
# Variance 5.9160059020396584e+16
# St. Dev 243228409.15566707
# Skew 0.0008874165560301696
# ----

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# explore the relationship between each application & the total DL+UL data

# %%
sample_data = tele_dataf.sample(frac=0.000099)
print(sample_data.shape)
sum_column = sample_data["Total DL (Bytes)"] + sample_data["Total UL (Bytes)"]
# Out:
# (15, 52)

# %%
sample_data.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'Activity Duration DL (ms)', 'Activity Duration UL (ms)', 'Dur. (ms).1',
#        'Handset Manufacturer', 'Handset Type', 'Nb of sec with Vol DL < 6250B',
#        'Nb of sec with Vol UL < 1250B', 'Social Media DL (Bytes)',
#        'Social Media UL (Bytes)', 'Google DL (Bytes)', 'Google UL (Bytes)',
#        'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)',
#        'Youtube UL (Bytes)', 'Netflix DL (Bytes)', 'Netflix UL (Bytes)',
#        'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)',
#        'Other UL (Bytes)', 'Total UL (Bytes)', 'Total DL (Bytes)',
#        'total_google', 'total_email', 'total_gaming', 'total_youtube',
#        'total_netflix', 'total_social', 'total_other'],
#       dtype='object')

# %%
tele_dataf["Youtube_Total_Data"]=tele_dataf["Youtube DL (Bytes)"]+tele_dataf["Youtube UL (Bytes)"]
tele_dataf["Google_Total_Data"]=tele_dataf["Google DL (Bytes)"]+tele_dataf["Google UL (Bytes)"]
tele_dataf["Email_Total_Data"]=tele_dataf["Email DL (Bytes)"]+tele_dataf["Email UL (Bytes)"]
tele_dataf["Social_Media_Total_Data"]=tele_dataf["Social Media DL (Bytes)"]+tele_dataf["Social Media UL (Bytes)"]
tele_dataf["Netflix_Total_Data"]=tele_dataf["Netflix DL (Bytes)"]+tele_dataf["Netflix UL (Bytes)"]
tele_dataf["Gaming_Total_Data"]=tele_dataf["Gaming DL (Bytes)"]+tele_dataf["Gaming UL (Bytes)"]
tele_dataf["Other_Total_Data"]=tele_dataf["Other DL (Bytes)"]+tele_dataf["Other UL (Bytes)"]
tele_dataf["Total UL and DL"]=tele_dataf["Total UL (Bytes)"]+tele_dataf["Total DL (Bytes)"]

# %%
columns = ['MSISDN/Number', 'Youtube_Total_Data', 'Google_Total_Data', 'Email_Total_Data','Social_Media_Total_Data', 'Netflix_Total_Data', 'Gaming_Total_Data', 'Other_Total_Data', 'Total UL and DL']

user_ratio_usage= tele_dataf[columns].groupby('MSISDN/Number').sum()
user_ratio_usage.head(10)
# Out:
#                Youtube_Total_Data  Google_Total_Data  Email_Total_Data  \
# MSISDN/Number
# 3.360100e+10           21624548.0          4389005.0         1331362.0
# 3.360100e+10           12432223.0          5334863.0         3307781.0
# 3.360100e+10           21333570.0          3443126.0         3205380.0
# 3.360101e+10            6977321.0          9678493.0         2284670.0
# 3.360101e+10           41533002.0         18499616.0         3305469.0
# 3.360101e+10           34347122.0         15263134.0         7848596.0
# 3.360101e+10           26431335.0         10196403.0         1358959.0
# 3.360101e+10           18892740.0         12023614.0         2215563.0
# 3.360101e+10           63443802.0         14134211.0         4599825.0
# 3.360102e+10           28569712.0         12935169.0         2783280.0
#
#                Social_Media_Total_Data  Netflix_Total_Data  Gaming_Total_Data  \
# MSISDN/Number
# 3.360100e+10                 2232135.0          27180981.0       8.124587e+08
# 3.360100e+10                 2660565.0          11221763.0       1.197501e+08
# 3.360100e+10                 3195623.0          19353900.0       5.388277e+08
# 3.360101e+10                  280294.0           1942092.0       3.911261e+08
# 3.360101e+10                 2912542.0          49201724.0       1.314798e+09
# 3.360101e+10                 3792912.0          30315501.0       5.116358e+08
# 3.360101e+10                 2769627.0          45812397.0       5.484611e+08
# 3.360101e+10                 1782692.0          15292840.0       2.823644e+08
# 3.360101e+10                 5288685.0          54216117.0       8.330880e+08
# 3.360102e+10                  956775.0          35525071.0       6.470957e+08
#
#                Other_Total_Data  Total UL and DL
# MSISDN/Number
# 3.360100e+10       3.865709e+08     8.786906e+08
# 3.360100e+10       2.817101e+08     1.568596e+08
# 3.360100e+10       5.016937e+08     5.959665e+08
# 3.360101e+10       3.527970e+07     4.223207e+08
# 3.360101e+10       8.048045e+08     1.457411e+09
# 3.360101e+10       4.923728e+08     6.152172e+08
# 3.360101e+10       2.248887e+08     6.547231e+08
# 3.360101e+10       1.782015e+08     3.326604e+08
# 3.360101e+10       1.041883e+09     9.901322e+08
# 3.360102e+10       1.383392e+08     7.324638e+08

# %%
apps_columns = ['Dur. (ms)','MSISDN/Number', 'Youtube_Total_Data', 'Google_Total_Data', 'Email_Total_Data','Social_Media_Total_Data', 'Netflix_Total_Data', 'Gaming_Total_Data', 'Other_Total_Data', 'Total UL and DL']

# %%
user_ratio_usage = tele_dataf[apps_columns]

user_ratio_usage.columns
# Out:
# Index(['Dur. (ms)', 'MSISDN/Number', 'Youtube_Total_Data', 'Google_Total_Data',
#        'Email_Total_Data', 'Social_Media_Total_Data', 'Netflix_Total_Data',
#        'Gaming_Total_Data', 'Other_Total_Data', 'Total UL and DL'],
#       dtype='object')

# %%
plot_scatter(user_ratio_usage,'Gaming_Total_Data', 'Total UL and DL', 'Total Data Vs. Gaming Data usage (MegaBytes)')

# %%
plot_scatter(user_ratio_usage.sample(10000), 'Youtube_Total_Data', 'Total UL and DL', 'Total Data Vs. Youtube_Total_Data (MegaBytes)')

# %%
plot_scatter(user_ratio_usage.sample(10000), 'Email_Total_Data', 'Total UL and DL', 'Total Data Vs. Email_Total_Data (MegaBytes)')

# %%
plot_scatter(user_ratio_usage.sample(10000), 'Social_Media_Total_Data', 'Total UL and DL', 'Total Data Vs. Social_Media_Total_Data (MegaBytes)')

# %%
plot_scatter(user_ratio_usage.sample(10000), 'Netflix_Total_Data', 'Total UL and DL', 'Total Data Vs. Netflix_Total_Data (MegaBytes)')

# %%
plot_scatter(user_ratio_usage.sample(10000), 'Other_Total_Data', 'Total UL and DL', 'Total Data Vs. Other_Total_Data ')

# %% [markdown]
# Variable transformations

# %% [markdown]
# segmenting the users into top 5 decile classes

# %%
# compute the total dl and ul
tele_dataf['total_data'] = tele_dataf["Total DL (Bytes)"] + tele_dataf["Total UL (Bytes)"]

# compute the decile classes
tele_dataf['decile'] = pd.qcut(tele_dataf['Dur. (ms)'],10, duplicates='drop')

ax=tele_dataf.groupby('decile')['total_data'].sum().head(5).plot(kind='bar', xticks=[0,1,2,3,4])
ax.set_xticklabels(['First','Second','Third','Fourth','Fifth'])
ax.set_ylabel('Data Durations')
# Out:
# /tmp/ipykernel_319022/2030566624.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ax=telecom_df.groupby('decile')['total_data'].sum().head(5).plot(kind='bar', xticks=[0,1,2,3,4])
# Text(0, 0.5, 'Data Durations')

# %% [markdown]
# Correlation Analysis

# %%
columns = ['Youtube_Total_Data', 'Google_Total_Data', 'Email_Total_Data','Social_Media_Total_Data', 'Netflix_Total_Data', 'Gaming_Total_Data', 'Other_Total_Data', 'Total UL and DL']
corr = user_ratio_usage[columns].corr()
corr
# Out:
#                          Youtube_Total_Data  Google_Total_Data  \
# Youtube_Total_Data                 1.000000           0.002635
# Google_Total_Data                  0.002635           1.000000
# Email_Total_Data                  -0.003098          -0.000386
# Social_Media_Total_Data            0.000568          -0.001907
# Netflix_Total_Data                 0.003252          -0.001997
# Gaming_Total_Data                 -0.003141          -0.000893
# Other_Total_Data                   0.003089          -0.001647
# Total UL and DL                    0.034769           0.013480
#
#                          Email_Total_Data  Social_Media_Total_Data  \
# Youtube_Total_Data              -0.003098                 0.000568
# Google_Total_Data               -0.000386                -0.001907
# Email_Total_Data                 1.000000                 0.004282
# Social_Media_Total_Data          0.004282                 1.000000
# Netflix_Total_Data               0.001409                 0.001497
# Gaming_Total_Data               -0.000511                 0.001559
# Other_Total_Data                -0.001096                 0.005635
# Total UL and DL                  0.003907                 0.005881
#
#                          Netflix_Total_Data  Gaming_Total_Data  \
# Youtube_Total_Data                 0.003252          -0.003141
# Google_Total_Data                 -0.001997          -0.000893
# Email_Total_Data                   0.001409          -0.000511
# Social_Media_Total_Data            0.001497           0.001559
# Netflix_Total_Data                 1.000000          -0.003278
# Gaming_Total_Data                 -0.003278           1.000000
# Other_Total_Data                  -0.008701          -0.002966
# Total UL and DL                    0.034635           0.998254
#
#                          Other_Total_Data  Total UL and DL
# Youtube_Total_Data               0.003089         0.034769
# Google_Total_Data               -0.001647         0.013480
# Email_Total_Data                -0.001096         0.003907
# Social_Media_Total_Data          0.005635         0.005881
# Netflix_Total_Data              -0.008701         0.034635
# Gaming_Total_Data               -0.002966         0.998254
# Other_Total_Data                 1.000000        -0.002724
# Total UL and DL                 -0.002724         1.000000

# %%
plot_heatmap(corr, "Correlation of Usage of User Data Volume")

# %% [markdown]
# Dimensionality Reduction

# %%
numeric_df = user_ratio_usage.select_dtypes(include='float64')

# %%
numeric_df.describe()
# Out:
#           Dur. (ms)  MSISDN/Number  Youtube_Total_Data  Google_Total_Data  \
# count  1.485060e+05   1.485060e+05        1.485060e+05       1.485060e+05
# mean   1.050841e+05   4.190654e+10        2.264244e+07       7.808063e+06
# std    8.107274e+04   2.450976e+12        9.247684e+06       3.516724e+06
# min    7.142000e+03   3.360100e+10        7.890300e+04       4.033000e+04
# 25%    5.824875e+04   3.365131e+10        1.599374e+07       4.944994e+06
# 50%    8.639900e+04   3.366371e+10        2.266131e+07       7.815669e+06
# 75%    1.329328e+05   3.368352e+10        2.929824e+07       1.068307e+07
# max    1.859336e+06   8.823971e+14        4.519008e+07       1.552878e+07
#
#        Email_Total_Data  Social_Media_Total_Data  Netflix_Total_Data  \
# count      1.485060e+05             1.485060e+05        1.485060e+05
# mean       2.259188e+06             1.828066e+06        2.262914e+07
# std        1.071152e+06             1.035638e+06        9.260477e+06
# min        8.359000e+03             1.563000e+03        9.843200e+04
# 25%        1.359336e+06             9.321828e+05        1.598016e+07
# 50%        2.264186e+06             1.825931e+06        2.263632e+07
# 75%        3.160024e+06             2.727493e+06        2.928832e+07
# max        4.518036e+06             3.650861e+06        4.519815e+07
#
#        Gaming_Total_Data  Other_Total_Data  Total UL and DL
# count       1.485060e+05      1.485060e+05     1.485060e+05
# mean        4.303538e+08      4.294152e+08     4.957834e+08
# std         2.440569e+08      2.432284e+08     2.444146e+08
# min         3.063580e+05      1.490450e+05     2.895611e+07
# 25%         2.187362e+08      2.186682e+08     2.845286e+08
# 50%         4.316585e+08      4.300438e+08     4.969225e+08
# 75%         6.415282e+08      6.398960e+08     7.065677e+08
# max         8.592028e+08      8.595209e+08     9.559848e+08

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(numeric_df)
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(numeric_df)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca.fit(scaled_data)
# Out:
# PCA(n_components=10)

# %%
x_pca = pca.transform(scaled_data)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_pca[:,4],x_pca[:,1],c=user_ratio_usage['Total UL and DL'],cmap='rainbow')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
from sklearn.decomposition import PCA
pca = PCA().fit(numeric_df)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlim(0,7.1)
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %%
from sklearn.decomposition import PCA 
sklearn_pca = PCA(n_components=6)
Y_sklearn = sklearn_pca.fit_transform(numeric_df)
Y_sklearn
# Out:
# array([[-8.24157941e+09,  2.02724828e+08, -2.49667936e+08,
#          1.06903442e+07,  4.02451815e+05, -4.11174751e+06],
#        [-8.22468751e+09, -2.76030736e+08,  1.13646232e+08,
#         -3.03315080e+07,  2.66899041e+06, -4.05441500e+06],
#        [-8.14591452e+09,  2.74618631e+08, -1.56004043e+07,
#         -1.28958714e+07,  7.56271423e+06,  9.60396195e+05],
#        ...,
#        [-8.24309199e+09, -2.89683426e+08,  2.86374237e+08,
#         -1.24669611e+07, -1.31599092e+07, -6.20593035e+06],
#        [-8.28465173e+09, -1.91028452e+08, -2.96239219e+08,
#          5.38446258e+06,  6.78466906e+06, -3.22809682e+05],
#        [-8.28691972e+09,  1.21448553e+08,  3.86221651e+08,
#          1.53795441e+07,  2.90712682e+05, -1.31627843e+06]])

# %%
#export user overview data to csv

user_ratio_usage.to_csv('../data/user_overview_data.csv',index=False)
